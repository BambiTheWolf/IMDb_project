# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
page = requests.get("https://www.imdb.com/list/ls064287418/")
page
page.status_code
page.content
soup = BeautifulSoup(page.content, "html.parser")
#print(soup.prettify())
genres = soup.find_all('span', class_ = "genre")
genres = str(genres)
genres = genres.replace('<span class="genre">','').replace('            </span>, \n',' ').replace('\n, ',' ').replace('            </span>]','')
genres.split('Cri')
# Out:
# ['[\n',
#  'me, Drama, Thriller ',
#  'me, Drama, Horror ',
#  'me, Drama, Thriller ',
#  'me, Drama, Mystery ',
#  'me, Drama, Mystery ',
#  'me, Drama, Thriller Action, Adventure, Comedy Comedy, ',
#  'me Comedy, ',
#  'me, Sci-Fi Action, ',
#  'me, Sci-Fi ',
#  'me, Thriller Action, ',
#  'me, Drama Horror, Mystery, Thriller Action, ',
#  'me, Drama ',
#  'me, Mystery, Thriller Animation, Adventure, Comedy ',
#  'me, Drama, Thriller Action, ',
#  'me, Drama Action, ',
#  'me, Thriller Action, ',
#  'me, Thriller Action, ',
#  'me, Thriller ',
#  'me, Drama, Thriller Action, ',
#  'me, Thriller Action, ',
#  'me, Drama Action, ',
#  'me, Drama Action, ',
#  'me, Horror Action, ',
#  'me, Thriller Action, ',
#  'me, Thriller ',
#  'me, Drama, Romance ',
#  'me, Drama Drama, Mystery, Thriller ',
#  'me, Drama, Mystery ',
#  'me, Drama, Film-Noir Action, Adventure, Comedy Comedy, ',
#  'me ',
#  'me, Drama, Mystery Action, Adventure, ',
#  'me Action, Adventure, Comedy Action, ',
#  'me, Drama ',
#  'me, Drama, Mystery Comedy, ',
#  'me, Sport ',
#  'me, Drama, Horror ',
#  'me, Drama, Mystery Action, ',
#  'me Animation, Adventure, Comedy Action, ',
#  'me, Drama ',
#  'me, Drama, Thriller Action, ',
#  'me, Drama Action, Drama, Thriller ',
#  'me, Drama, Mystery Action, ',
#  'me, Thriller Biography, ',
#  'me, Drama Action, Comedy, ',
#  'me ',
#  'me, Drama, Horror Action, ',
#  'me, Thriller Drama, Thriller Action, Adventure, ',
#  'me ',
#  'me, Drama, Mystery ',
#  'me, Horror, Thriller Action, Comedy, ',
#  'me Drama, Thriller ',
#  'me, Drama ',
#  'me, Drama, Thriller Action, ',
#  'me, Drama ',
#  'me, Horror, Mystery ',
#  'me, Horror, Mystery ',
#  'me, Film-Noir, Thriller ',
#  'me, Mystery, Thriller Comedy, ',
#  'me Action, ',
#  'me, Drama ',
#  'me, Drama, Horror Action, ',
#  'me, Thriller Adventure, ',
#  'me, Drama Action, ',
#  'me, Drama Action, Adventure, ',
#  'me Biography, ',
#  'me, Drama Action, ',
#  'me, Thriller ',
#  'me, Thriller Action, ',
#  'me, Thriller ',
#  'me, Drama, Mystery ',
#  'me, Horror, Mystery Action, ',
#  'me, Thriller Action, ',
#  'me, Drama ',
#  'me, Drama Comedy, ',
#  'me, Drama Action, ',
#  'me, Drama Action, Thriller Action, ',
#  'me, Drama ',
#  'me, Drama, Romance ',
#  'me, Drama ',
#  'me, Drama, Mystery Comedy, ',
#  'me Comedy, ',
#  'me, Musical ',
#  'me, Drama, Thriller Biography, ',
#  'me, Drama ',
#  'me, Drama, Romance Action, Comedy, ',
#  'me Biography, ',
#  'me, Drama ',
#  'me, Romance, Thriller Action, Adventure, Mystery']
